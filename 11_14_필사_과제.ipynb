# %% [markdown]
# <a href="https://colab.research.google.com/github/jiminmini/mini/blob/ESAA_OB/11_14_%ED%95%84%EC%82%AC_%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**[개념 정리]**
#
# **[합성곱 신경망]**
# - 이미지나 영상 처리에 유용
# - 입력층
# - 합성곱층
# - 폴링층
# - 완전연결층
# - 출력층
#
# **[합성곱층]**
# - 입력 데이터에서 특성 추출하는 역할 수행
#
# **[폴링층]**
# - 특성 맵의 차원을 다운 샘플링하여 연산량을 감소시킴
#
# - 폴링 연산: 최대 폴링, 평균 폴링
#
# **[1D,2D,3D 합성곱]**
# - 1D 합성곱: 필터가 시간을 축으로 좌우로만 이동
# - 2D 합성곱: 필터가 방향 2개로 움직이는 형태
# - 3D 합성곱: 필터가 움직이는 방향이 3개

# %% [markdown]
# #**[코드 필사]**

# %%
#코드 없음
